# %%
from geneticalgorithm4 import *

# %%
not_nan
# Out:
#      flag  lat_index  lon_index
# 0       s          0         86
# 1       s          0         87
# 2       s          1         86
# 3       s          1         87
# 4       s          2         81
# ...   ...        ...        ...
# 4013    s        508         54
# 4014    s        508         55
# 4015    s        508         56
# 4016    s        509         56
# 4017    s        510         53
#
# [3147 rows x 3 columns]

# %%
### 5e7
number_generations = 50
population_size = 500
chromosome_length = 20

args = [number_generations,population_size,chromosome_length]
chrom_best,f_best,f_mean = ga(*args)

for i in range(number_generations+1):
    df_best = not_nan.loc[chrom_best[i,:]]
    df_best.to_csv(f'data/processed/ga-results-22/gen-{i}.csv',index=True)

g_plot = np.arange(number_generations+1)
plt.figure(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')
plt.plot(g_plot,f_mean,label='average')
plt.plot(g_plot,f_best,label='maximum')
plt.xlabel('generation')
plt.ylabel('fitness value')
plt.legend()
plt.savefig('figures/ga-convergence-22.png')
# Out:
# generation 0: done
# generation 1: done
# generation 2: done
# generation 3: done
# generation 4: done
# generation 5: done
# generation 6: done
# generation 7: done
# generation 8: done
# generation 9: done
# generation 10: done
# generation 11: done
# generation 12: done
# generation 13: done
# generation 14: done
# generation 15: done
# generation 16: done
# generation 17: done
# generation 18: done
# generation 19: done
# generation 20: done
# generation 21: done
# generation 22: done
# generation 23: done
# generation 24: done
# generation 25: done
# generation 26: done
# generation 27: done
# generation 28: done
# generation 29: done
# generation 30: done
# generation 31: done
# generation 32: done
# generation 33: done
# generation 34: done
# generation 35: done
# generation 36: done
# generation 37: done
# generation 38: done
# generation 39: done
# generation 40: done
# generation 41: done
# generation 42: done
# generation 43: done
# generation 44: done
# ...

# %%
run = 22

df = pandas.read_csv(f'data/processed/ga-results-{run}/gen-50.csv')

ds = xr.open_dataset('data/processed/map.nc')
uk = ds.empty.values


for j in range(len(df)):
    uk[df.iloc[j]['lat_index'],df.loc[j]['lon_index']] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


placement_xr.to_netcdf(path=f'data/processed/ga-{run}.nc')

ds = xr.open_dataset(f'data/processed/ga-{run}.nc')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('darkgreen')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)

# %%
### 1e8

# %%
not_nan
# Out:
#      flag  lat_index  lon_index
# 0       s          1         86
# 1       s         16         82
# 2       s         17         80
# 3       s         18         80
# 4       s         32        117
# ...   ...        ...        ...
# 1167    s        508         51
# 1168    s        508         52
# 1169    s        508         53
# 1170    s        508         54
# 1171    s        508         55
#
# [1172 rows x 3 columns]

# %%
### 1e8
number_generations = 50
population_size = 500
chromosome_length = 20

args = [number_generations,population_size,chromosome_length]
chrom_best,f_best,f_mean = ga(*args)

for i in range(number_generations+1):
    df_best = not_nan.loc[chrom_best[i,:]]
    df_best.to_csv(f'data/processed/ga-results-23/gen-{i}.csv',index=True)

g_plot = np.arange(number_generations+1)
plt.figure(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')
plt.plot(g_plot,f_mean,label='average')
plt.plot(g_plot,f_best,label='maximum')
plt.xlabel('generation')
plt.ylabel('fitness value')
plt.legend()
plt.savefig('figures/ga-convergence-23.png')
# Out:
# generation 0: done
# generation 1: done
# generation 2: done
# generation 3: done
# generation 4: done
# generation 5: done
# generation 6: done
# generation 7: done
# generation 8: done
# generation 9: done
# generation 10: done
# generation 11: done
# generation 12: done
# generation 13: done
# generation 14: done
# generation 15: done
# generation 16: done
# generation 17: done
# generation 18: done
# generation 19: done
# generation 20: done
# generation 21: done
# generation 22: done
# generation 23: done
# generation 24: done
# generation 25: done
# generation 26: done
# generation 27: done
# generation 28: done
# generation 29: done
# generation 30: done
# generation 31: done
# generation 32: done
# generation 33: done
# generation 34: done
# generation 35: done
# generation 36: done
# generation 37: done
# generation 38: done
# generation 39: done
# generation 40: done
# generation 41: done
# generation 42: done
# generation 43: done
# generation 44: done
# ...

# %%
run = 23

df = pandas.read_csv(f'data/processed/ga-results-{run}/gen-50.csv')

ds = xr.open_dataset('data/processed/map.nc')
uk = ds.empty.values


for j in range(len(df)):
    uk[df.iloc[j]['lat_index'],df.loc[j]['lon_index']] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


placement_xr.to_netcdf(path=f'data/processed/ga-{run}.nc')

ds = xr.open_dataset(f'data/processed/ga-{run}.nc')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('darkgreen')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)

# %%
### 1e8
number_generations = 100
population_size = 1000
chromosome_length = 10

args = [number_generations,population_size,chromosome_length]
chrom_best,f_best,f_mean = ga(*args)

for i in range(number_generations+1):
    df_best = not_nan.loc[chrom_best[i,:]]
    df_best.to_csv(f'data/processed/ga-results-24/gen-{i}.csv',index=True)

g_plot = np.arange(number_generations+1)
plt.figure(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')
plt.plot(g_plot,f_mean,label='average')
plt.plot(g_plot,f_best,label='maximum')
plt.xlabel('generation')
plt.ylabel('fitness value')
plt.legend()
plt.savefig('figures/ga-convergence-24.png')
# Out:
# generation 0: done
# generation 1: done
# generation 2: done
# generation 3: done
# generation 4: done
# generation 5: done
# generation 6: done
# generation 7: done
# generation 8: done
# generation 9: done
# generation 10: done
# generation 11: done
# generation 12: done
# generation 13: done
# generation 14: done
# generation 15: done
# generation 16: done
# generation 17: done
# generation 18: done
# generation 19: done
# generation 20: done
# generation 21: done
# generation 22: done
# generation 23: done
# generation 24: done
# generation 25: done
# generation 26: done
# generation 27: done
# generation 28: done
# generation 29: done
# generation 30: done
# generation 31: done
# generation 32: done
# generation 33: done
# generation 34: done
# generation 35: done
# generation 36: done
# generation 37: done
# generation 38: done
# generation 39: done
# generation 40: done
# generation 41: done
# generation 42: done
# generation 43: done
# generation 44: done
# ...

# %%
### only stream without established range, i.e aggregate = 0

number_generations = 50
population_size = 500
chromosome_length = 20

args = [number_generations,population_size,chromosome_length]
chrom_best,f_best,f_mean = ga(*args)

for i in range(number_generations+1):
    df_best = not_nan.loc[chrom_best[i,:]]
    df_best.to_csv(f'data/processed/ga-results-25/gen-{i}.csv',index=True)

g_plot = np.arange(number_generations+1)
plt.figure(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')
plt.plot(g_plot,f_mean,label='average')
plt.plot(g_plot,f_best,label='maximum')
plt.xlabel('generation')
plt.ylabel('fitness value')
plt.legend()
plt.savefig('figures/ga-convergence-25.png')
# Out:
# generation 0: done
# generation 1: done
# generation 2: done
# generation 3: done
# generation 4: done
# generation 5: done
# generation 6: done
# generation 7: done
# generation 8: done
# generation 9: done
# generation 10: done
# generation 11: done
# generation 12: done
# generation 13: done
# generation 14: done
# generation 15: done
# generation 16: done
# generation 17: done
# generation 18: done
# generation 19: done
# generation 20: done
# generation 21: done
# generation 22: done
# generation 23: done
# generation 24: done
# generation 25: done
# generation 26: done
# generation 27: done
# generation 28: done
# generation 29: done
# generation 30: done
# generation 31: done
# generation 32: done
# generation 33: done
# generation 34: done
# generation 35: done
# generation 36: done
# generation 37: done
# generation 38: done
# generation 39: done
# generation 40: done
# generation 41: done
# generation 42: done
# generation 43: done
# generation 44: done
# ...

# %%
run = 25

df = pandas.read_csv(f'data/processed/ga-results-{run}/gen-50.csv')

ds = xr.open_dataset('data/processed/map.nc')
uk = ds.empty.values


for j in range(len(df)):
    uk[df.iloc[j]['lat_index'],df.loc[j]['lon_index']] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


# placement_xr.to_netcdf(path=f'data/processed/ga-{run}.nc')

ds = xr.open_dataset(f'data/processed/ga-{run}.nc')

ds['lat'] = ds.lat.assign_attrs(units='degrees')
ds['lat'] = ds.lat.assign_attrs(long_name='latitude')
ds['lon'] = ds.lon.assign_attrs(units='degrees')
ds['lon'] = ds.lon.assign_attrs(long_name='longitude')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('#003300')
# cmap.set_bad('white')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)

# %%
sol_power = 0
plt.figure()
for i in range(len(df)):
    curve = s_power[:,df.loc[i,('lat_index')],df.loc[i,('lon_index')]]
    sol_power += curve
    plt.plot(ds_range.time.values,curve,label=f'{df.iloc[i,0]}')
    
    
plt.figure()
plt.plot(ds_range.time.values,sol_power)
    
    
sol_mean = np.mean(sol_power)
rmsd = np.sqrt(np.mean((sol_power-sol_mean)**2))
print((sol_mean**2)/rmsd)

f_best[-1]
# Out:
# 18965478092.166286
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 17>()
#      14 rmsd = np.sqrt(np.mean((sol_power-sol_mean)**2))
#      15 print((sol_mean**2)/rmsd)
# ---> 17 f_best[-1]
#
# NameError: name 'f_best' is not defined

# %%
pf_mean = np.mean(pf)
pf_scaled = pf*sol_mean/pf_mean
rmsd = np.sqrt(np.mean((pf_scaled-sol_mean)**2))
print((sol_mean**2)/rmsd)
# Out:
# 12917620011.647476

# %%
#####

# %%
fig,ax1 = plt.subplots(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')

color = 'firebrick'
ax1.plot(ds_range.time.values,sol_power/1e9,color=color)
ax1.set_xlabel('time')
ax1.set_ylabel('power generated by tidal stream [GW]',color=color)
ax1.tick_params(axis='y',labelcolor=color)


color = 'royalblue'
ax2 = ax1.twinx()
ax2.plot(ds_range.time.values,range_aggregate/1e9,color=color)
ax2.set_ylabel('power generated by tidal range [GW]',color=color)
ax2.tick_params(axis='y',labelcolor=color)


# plt.savefig('figures/for-report/ga-1e8combined-power.png')

# %%
fig,ax1 = plt.subplots(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')

color = 'firebrick'
ax1.plot(ds_range.time.values[:200],sol_power[:200]/1e9,color=color)
ax1.set_xlabel('time')
ax1.set_ylabel('power generated by tidal stream [GW]',color=color)
ax1.tick_params(axis='y',labelcolor=color)


color = 'royalblue'
ax2 = ax1.twinx()
ax2.plot(ds_range.time.values[:200],range_aggregate[:200]/1e9,color=color)
ax2.set_ylabel('power generated by tidal range [GW]',color=color)
ax2.tick_params(axis='y',labelcolor=color)


# plt.savefig('figures/for-report/ga-1e8combined-power-zoom.png')

# %%
long = -3.091
lat = 58.73
pf1 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.03
lat = 58.73
pf2 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.091
lat = 58.7027
pf3 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.03
lat = 58.7027
pf4 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

pf = pf1+pf2+pf3+pf4

fig,ax1 = plt.subplots(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')

color = 'firebrick'
ax1.plot(ds_range.time.values,pf/1e9,color=color)
ax1.set_xlabel('time')
ax1.set_ylabel('power generated by tidal stream [GW]',color=color)
ax1.tick_params(axis='y',labelcolor=color)


color = 'royalblue'
ax2 = ax1.twinx()
ax2.plot(ds_range.time.values,range_aggregate/1e9,color=color)
ax2.set_ylabel('power generated by tidal range [GW]',color=color)
ax2.tick_params(axis='y',labelcolor=color)


# plt.savefig('figures/for-report/ga-pfcombined-power.png')

# %%
fig,ax1 = plt.subplots(figsize=(12.8,9.6))
plt.style.use('seaborn-colorblind')

color = 'firebrick'
ax1.plot(ds_range.time.values[:200],pf[:200]/1e9,color=color)
ax1.set_xlabel('time')
ax1.set_ylabel('power generated by tidal stream [GW]',color=color)
ax1.tick_params(axis='y',labelcolor=color)


color = 'royalblue'
ax2 = ax1.twinx()
ax2.plot(ds_range.time.values[:200],range_aggregate[:200]/1e9,color=color)
ax2.set_ylabel('power generated by tidal range [GW]',color=color)
ax2.tick_params(axis='y',labelcolor=color)


# plt.savefig('figures/for-report/ga-pfcombined-power-zoom.png')

# %%
norm = np.mean(sol_power)/np.mean(range_aggregate)
norm1 = max(sol_power)/max(range_aggregate)

# %%
# %matplotlib notebook



plt.figure()
plt.plot(ds_range.time.values,sol_power/norm1)
plt.plot(ds_range.time.values,range_aggregate)
plt.plot(ds_range.time.values,(sol_power/norm1)+range_aggregate)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
long = -3.091
lat = 58.73
pf1 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.03
lat = 58.73
pf2 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.091
lat = 58.7027
pf3 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

long = -3.03
lat = 58.7027
pf4 = ds_stream_pow.power.sel(lon=long,lat=lat,method='nearest').values

pf = pf1+pf2+pf3+pf4

norm_baseline = np.mean(pf)/np.mean(range_aggregate)
norm1_baseline = max(pf)/max(range_aggregate)

plt.figure()
plt.plot(ds_range.time.values,pf/norm1_baseline)
plt.plot(ds_range.time.values,range_aggregate)
plt.plot(ds_range.time.values,pf/norm1_baseline+range_aggregate)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(ds_range.time.values,(pf/norm1_baseline)+range_aggregate)
plt.plot(ds_range.time.values,(sol_power/norm1)+range_aggregate)


print(np.mean((pf/norm1_baseline)+range_aggregate),np.mean((sol_power/norm1)+range_aggregate))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 2285226304.9152856 2587592774.6917014

# %%
long = -3.0909090
a = np.where(longitude==long)[0][0]
long = -3.0303030
b = np.where(longitude==long)[0][0]

lat = 58.72973
c = np.where(latitude==lat)[0][0]
lat = 58.7027
d = np.where(latitude==lat)[0][0]

print(a,b,c,d)
# Out:
# 114 115 397 396

# %%
ds = xr.open_dataset('data/processed/map.nc')
uk = ds.empty.values


uk[c,a] = -10
uk[c,b] = -10
uk[d,a] = -10
uk[d,b] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


# placement_xr.to_netcdf(path=f'data/processed/pentlandfirth.nc')

ds = xr.open_dataset(f'data/processed/pentlandfirth.nc')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('#003300')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)

# %%
ds_r_sol = xr.open_dataset(f'data/processed/ga-21-sol-modified.nc')
uk = ds_r_sol.placement.values

df = pandas.read_csv(f'data/processed/ga-results-25/gen-50.csv')



for j in range(len(df)):
    uk[df.iloc[j]['lat_index'],df.loc[j]['lon_index']] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


# placement_xr.to_netcdf(path=f'data/processed/ga-21-sol-modified-stream.nc')

ds = xr.open_dataset(f'data/processed/ga-21-sol-modified-stream.nc')

ds['lat'] = ds.lat.assign_attrs(units='degrees')
ds['lat'] = ds.lat.assign_attrs(long_name='latitude')
ds['lon'] = ds.lon.assign_attrs(units='degrees')
ds['lon'] = ds.lon.assign_attrs(long_name='longitude')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('#003300')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)  
# plt.savefig('figures/for-report/ga-1e8combined-map.png')

# %%
ds_r_sol = xr.open_dataset(f'data/processed/ga-21-sol-modified.nc')
uk = ds_r_sol.placement.values

uk[c,a] = -10
uk[c,b] = -10
uk[d,a] = -10
uk[d,b] = -10
    

placement_xr = xr.Dataset({
    'placement': xr.DataArray(
        data=uk,
        coords={'lat': latitude,
                'lon': longitude},
        dims=['lat','lon'])})


# placement_xr.to_netcdf(path=f'data/processed/ga-21-sol-modified-stream-pf.nc')

ds = xr.open_dataset(f'data/processed/ga-21-sol-modified-stream-pf.nc')

ds['lat'] = ds.lat.assign_attrs(units='degrees')
ds['lat'] = ds.lat.assign_attrs(long_name='latitude')
ds['lon'] = ds.lon.assign_attrs(units='degrees')
ds['lon'] = ds.lon.assign_attrs(long_name='longitude')

cmap = mpl.cm.get_cmap('magma').copy()
cmap.set_over('dodgerblue')
cmap.set_under('tomato')
# cmap.set_over('cyan')
# cmap.set_under('magenta')
cmap.set_bad('#003300')

ds.placement.plot(size=10,aspect=1,vmin=0,vmax=5,cmap=cmap)  
# plt.savefig('figures/for-report/ga-pfcombined-map.png')
